# %% [markdown]
# ### Google Drive 연결

# %%
cd /content/drive/MyDrive/TABA
# Out:
# /content/drive/MyDrive/TABA

# %% [markdown]
# # Git & Github 사용법

# %% [markdown]
# ## Github 처음 설정

# %% [markdown]
# ### Git ID 설정

# %%
# !git config --global user.email kimpyo9357@naver.com
# !git config --global user.name kimpyo9357

# %% [markdown]
# ### Git 사용할 폴더 설정

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %% [markdown]
# ### Git 내용 추가

# %%
# !git add .

# %%
# !git commit -m "first commit"
# Out:
# [master (root-commit) 6682049] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 Untitled0.ipynb

# %% [markdown]
# ### Github Repository 연결

# %%
# !git remote add origin https://<username>:<token>@github.com/kimpyo9357/TABA.git

# %% [markdown]
# ### Github에 내용 올리기

# %%
# !git push -u origin master
# Out:
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 918 bytes | 83.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/kimpyo9357/TABA.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %% [markdown]
# ## 수정된 파일 올리기

# %%
# !git add .

# %%
# !git commit -m "second commit"
# Out:
# [master 4792082] second commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push -u origin master
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 1.50 KiB | 153.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/kimpyo9357/TABA.git
#    6682049..4792082  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %% [markdown]
# ## Github에서 파일 가져오기

# %%
# !git clone https://github.com/kimpyo9357/Iris
# Out:
# Cloning into 'Iris'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 0), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.

# %%
cd Iris
# Out:
# /content/drive/MyDrive/TABA/Iris
